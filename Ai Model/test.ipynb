# %%
print("Working")
# Out:
# Working

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/mnt/c/Users/aumpa/Downloads/archive/renewable_hydrogen_dataset.csv')

# %%
df.head(10)
# Out:
#    p_id2  start_year  season_days_injured  total_days_injured  \
# 0      1        2001                   99                  72
# 1      2        2012                   46                  40
# 2      3        2020                    8                  74
# 3      4        2000                   20                 178
# 4      5        2022                   45                 441
# 5      6        2013                   26                 231
# 6      7        2004                   32                  67
# 7      8        2002                   89                 469
# 8      9        2014                   55                 361
# 9     10        2020                   69                 152
#
#    season_minutes_played  season_games_played  season_matches_in_squad  \
# 0                   1242                   32                       39
# 1                   1555                   30                       28
# ...

# %%
df.isnull().sum()
# Out:
# p_id2                              0
# start_year                         0
# season_days_injured                0
# total_days_injured                 0
# season_minutes_played              0
# season_games_played                0
# season_matches_in_squad            0
# total_minutes_played               0
# total_games_played                 0
# dob                                0
# height_cm                          0
# weight_kg                          0
# nationality                        0
# work_rate                          0
# pace                               0
# physic                             0
# fifa_rating                        0
# position                           0
# age                                0
# bmi                                0
# work_rate_numeric                  0
# position_numeric                   0
# significant_injury_prev_season     0
# cumulative_days_injured            0
# season_days_injured_prev_season    0
# ...

# %%
df.describe()
# Out:
#             p_id2   start_year  season_days_injured  total_days_injured  \
# count  2535.00000  2535.000000          2535.000000         2535.000000
# mean   1268.00000  2012.172781            49.181460          251.058383
# std     731.93579     7.178586            28.958647          144.830406
# min       1.00000  2000.000000             0.000000            0.000000
# 25%     634.50000  2006.000000            24.000000          129.000000
# 50%    1268.00000  2012.000000            50.000000          250.000000
# 75%    1901.50000  2018.000000            74.000000          377.000000
# max    2535.00000  2024.000000            99.000000          499.000000
#
#        season_minutes_played  season_games_played  season_matches_in_squad  \
# count            2535.000000          2535.000000              2535.000000
# mean             1505.323077            18.423274                24.478107
# std               869.419784            10.876664                14.373808
# ...

# %%
df2 = pd.read_csv('/mnt/c/Users/aumpa/Downloads/archive/renewable_hydrogen_dataset_2535.csv')
df.head(10)
# Out:
#    p_id2  start_year  season_days_injured  total_days_injured  \
# 0      1        2001                   99                  72
# 1      2        2012                   46                  40
# 2      3        2020                    8                  74
# 3      4        2000                   20                 178
# 4      5        2022                   45                 441
# 5      6        2013                   26                 231
# 6      7        2004                   32                  67
# 7      8        2002                   89                 469
# 8      9        2014                   55                 361
# 9     10        2020                   69                 152
#
#    season_minutes_played  season_games_played  season_matches_in_squad  \
# 0                   1242                   32                       39
# 1                   1555                   30                       28
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2535 entries, 0 to 2534
# Data columns (total 26 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   p_id2                            2535 non-null   int64
#  1   start_year                       2535 non-null   int64
#  2   season_days_injured              2535 non-null   int64
#  3   total_days_injured               2535 non-null   int64
#  4   season_minutes_played            2535 non-null   int64
#  5   season_games_played              2535 non-null   int64
#  6   season_matches_in_squad          2535 non-null   int64
#  7   total_minutes_played             2535 non-null   int64
#  8   total_games_played               2535 non-null   int64
#  9   dob                              2535 non-null   object
#  10  height_cm                        2535 non-null   int64
#  11  weight_kg                        2535 non-null   int64
# ...

# %%
print(df2.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2535 entries, 0 to 2534
# Data columns (total 26 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   p_id2                            2535 non-null   int64
#  1   start_year                       2535 non-null   int64
#  2   season_days_injured              2535 non-null   int64
#  3   total_days_injured               2535 non-null   int64
#  4   season_minutes_played            2535 non-null   int64
#  5   season_games_played              2535 non-null   int64
#  6   season_matches_in_squad          2535 non-null   int64
#  7   total_minutes_played             2535 non-null   int64
#  8   total_games_played               2535 non-null   int64
#  9   dob                              2535 non-null   object
#  10  height_cm                        2535 non-null   int64
#  11  weight_kg                        2535 non-null   int64
# ...
